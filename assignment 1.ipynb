# %%
my_dict = {
    "name": "Rahul",
    "rollno": 12,
    "age": 18,
    "course": "B.Tech",
    "marks": 85
}

# Display dictionary
print("Student information:")
print(my_dict)
# Out:
# Student information:
# {'name': 'Rahul', 'rollno': 12, 'age': 18, 'course': 'B.Tech', 'marks': 85}

# %%
# Q1 P2
# Add information
my_dict["city"] = "Pune"
print("After adding city:")
print(my_dict)

# Delete information
del my_dict["age"]
print("After deleting age:")
print(my_dict)
# Out:
# After adding city:
# {'name': 'Rahul', 'rollno': 12, 'age': 18, 'course': 'B.Tech', 'marks': 85, 'city': 'Pune'}
# After deleting age:
# {'name': 'Rahul', 'rollno': 12, 'course': 'B.Tech', 'marks': 85, 'city': 'Pune'}

# %%
# Q2
list1 = ["name", "panel", "rollno"]
list2 = ["ABC", "B", 34]

my_dict = dict(zip(list1, list2))

print(my_dict)
# Out:
# {'name': 'ABC', 'panel': 'B', 'rollno': 34}

# %%
# Q3
my_dict = {
    "name": "ABC",
    "panel": "B",
    "rollno": 34,
    "marks": [65, 87, 67, 94]
}

print(sorted(my_dict))
# Out:
# ['marks', 'name', 'panel', 'rollno']

# %%
# Q4
my_dict = {
    "name": "ABC",
    "panel": "B",
    "rollno": 34
}

keys = list(my_dict.keys())
values = list(my_dict.values())

print("Keys:", keys)
print("Values:", values)
# Out:
# Keys: ['name', 'panel', 'rollno']
# Values: ['ABC', 'B', 34]

# %%
# Q5
mydict = {
    "marks1": 23,
    "marks2": 123,
    "marks3": 43,
    "marks4": 13,
    "marks5": 39
}

values = mydict.values()

mean = sum(values) / len(values)

print("Mean =", mean)
# Out:
# Mean = 48.2

# %%
# Q6
my_dict = {
    "name": ["Yash", "Neel", "Dev"],
    "rollno": [11, 12, 13],
    "marks": [78, 56, 98]
}

print("a) Name:", my_dict["name"][2])
print("b) Roll no:", my_dict["rollno"][1])
print("c) Greatest marks:", max(my_dict["marks"]))
# Out:
# a) Name: Dev
# b) Roll no: 12
# c) Greatest marks: 98

# %%
# Q7
string = input("Enter a string: ")

frequency = {}

for ch in string:
    if ch in frequency:
        frequency[ch] += 1
    else:
        frequency[ch] = 1

print("Frequency:", frequency)
# Out:
# Enter a string:  hello world
# Frequency: {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}

# %%
# Q8
numerator = int(input("Enter numerator: "))
denominator = int(input("Enter denominator: "))

quotient = numerator // denominator
remainder = numerator % denominator

result = (quotient, remainder)

print(result)
# Out:
# Enter numerator:  3
# Enter denominator:  9
# (0, 3)

# %%
# Q9
from datetime import date

d1 = int(input("Enter day of first date: "))
m1 = int(input("Enter month of first date: "))
y1 = int(input("Enter year of first date: "))

d2 = int(input("Enter day of second date: "))
m2 = int(input("Enter month of second date: "))
y2 = int(input("Enter year of second date: "))

date1 = date(y1, m1, d1)
date2 = date(y2, m2, d2)

difference = abs((date2 - date1).days)

print("Number of days between dates:", difference)
# Out:
# Enter day of first date:  2
# Enter month of first date:  10
# Enter year of first date:  2007
# Enter day of second date:  22
# Enter month of second date:  2
# Enter year of second date:  2026
# Number of days between dates: 6718
